# %%
import geopandas as gpd
import pandas as pd

# %%
# import shp file

gdf_pikine = gpd.read_file("C:/Users/bakho/Desktop/dgig_project/data/Dakar final/PIKINE/limites_parcelles_Pikine.shp")

gdf_pikine.head()
# Out:
#   région   départeme                commune VillageQua   CodeSectio  \
# 0  DAKAR  PIKINE\r\n  DIAMAGUENE SICAP MBAO       None  01230133017
# 1  DAKAR  PIKINE\r\n  DIAMAGUENE SICAP MBAO       None  01230133017
# 2  DAKAR  PIKINE\r\n  DIAMAGUENE SICAP MBAO       None  01230133017
# 3  DAKAR  PIKINE\r\n  DIAMAGUENE SICAP MBAO       None  01230133017
# 4  DAKAR  PIKINE\r\n  DIAMAGUENE SICAP MBAO       None  01230133017
#
#   lotissemen NumLot numParcell             nicad  SupLegale  ...  Numéro_de  \
# 0       None   None      01001  0123013301701001        0.0  ...       None
# 1       None   None      00973  0123013301700973        0.0  ...       None
# 2       None   None      00923  0123013301700923        0.0  ...       None
# 3       None     23      00129  0123013301700129        0.0  ...       None
# 4       None     35      00925  0123013301700925        0.0  ...       None
#
#   Date_de_d  E_mail  TitreParce SupReelle adresse TOPONYMIE  Shape_Leng  \
# ...

# %%
gdf_pikine.columns
# Out:
# Index(['région', 'départeme', 'commune', 'VillageQua', 'CodeSectio',
#        'lotissemen', 'NumLot', 'numParcell', 'nicad', 'SupLegale', 'SupBatie',
#        'TypeBatie', 'NbNivBat', 'SupNbatie', 'TypeDestin', 'Catocup',
#        'SourceDonn', 'TitreMere', 'TypeDocFon', 'NatJuri', 'TitulaireD',
#        'IdTitulair', 'Occupant', 'IdOccupant', 'ValLocativ', 'SupRelle',
#        'Numéro_de', 'Date_de_d', 'E_mail', 'TitreParce', 'SupReelle',
#        'adresse', 'TOPONYMIE', 'Shape_Leng', 'Shape_Area', 'geometry'],
#       dtype='object')
